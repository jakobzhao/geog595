# %%
# !pip install geocoder
import geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 3.2 MB/s
# ...

# %%
from google.colab import files
# Create data on to Google Drive
from google.colab import drive
# Mount your Drive to the Colab VM.
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
with open("/gdrive/MyDrive/geog595/gay-seattle-places-geocoded.csv", "w", encoding="utf8") as geofp:
    geofp.write("name, frequency, lat, lng\n")
    with open("/gdrive/MyDrive/geog595/gay-seattle-places.csv", "r", encoding="utf8") as fp:
        for line in fp.readlines():
            location = line.split(",")[0]
            freq = int(line.split(",")[1])
            try:
                g = geocoder.arcgis(location)
                lat = g.current_result.lat
                lng = g.current_result.lng
                geofp.write("%s, %d, %f, %f\n" % (location, freq, lat, lng))
                print(location, freq, lat, lng)
            except:
                pass
print("finished!")
# Out:
# seattle 648 47.60357000000005 -122.32944999999995
# washington 222 38.890370000000075 -77.03195999999997
# france 45 46.55941704400004 2.5505399530000545
# newyork 45 56.25000000000006 -5.283329999999978
# sanfrancisco 35 -8.98345999999998 -38.21677999999997
# rome 25 41.90322000000003 12.495650000000069
# vatican 23 41.90225000000004 12.45330000000007
# california 22 36.37410569300005 -119.27022999999997
# hollywood 20 26.01067000000006 -80.16025999999994
# king county 17 47.490118504000066 -121.80433656399998
# tacoma 17 47.255130000000065 -122.44163999999995
# oregon 16 43.938780241000075 -120.55856091199996
# united states 15 39.39870315600007 -99.41461918999994
# vietnam 12 16.166670000000067 107.83333000000005
# chicago 11 41.884250000000065 -87.63244999999995
# losangeles 10 34.053570000000036 -118.24544999999995
# america 9 39.39870315600007 -99.41461918999994
# olympia 8 47.03956000000005 -122.89165999999994
# newyork city 8 22.640870000000064 75.84844000000004
# ...
